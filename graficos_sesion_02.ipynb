# %%
import Pkg
Pkg.add("Plots")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Opus_jll ───────────────────── v1.3.2+0
#    Installed libfdk_aac_jll ─────────────── v2.0.2+0
#    Installed LERC_jll ───────────────────── v3.0.0+1
#    Installed JpegTurbo_jll ──────────────── v3.0.3+0
#    Installed GR_jll ─────────────────────── v0.73.6+0
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed Libmount_jll ───────────────── v2.40.1+0
#    Installed LoggingExtras ──────────────── v1.0.3
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.6+0
#    Installed Measures ───────────────────── v0.3.2
#    Installed ConcurrentUtilities ────────── v2.4.1
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Unitful ────────────────────── v1.20.0
#    Installed Contour ────────────────────── v0.6.3
#    Installed Xorg_xcb_util_image_jll ────── v0.4.0+1
#    Installed RecipesPipeline ────────────── v0.6.12
# ...

# %%
using Plots

# %%
plot(rand(10,5))

# %%
plot(rand(10),rand(10))

# %%
plot(sin)

# %%
plot([sin,cos],0[0,1:2π])
# Out:
# MethodError: no method matching getindex(::Int64, ::Int64, ::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#
# Closest candidates are:
#   getindex(::Number, ::Integer)
#    @ Base number.jl:96
#   getindex(::Number, ::Integer...)
#    @ Base number.jl:101
#   getindex(::Number)
#    @ Base number.jl:95
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[16]:1

# %%
plot!(title="Ejemplo funcion seno y coseno")
xlabel!("Radianes")
ylabel!("Funciones")

# %%
x = range(0,10,length=100)
y3 = @. sin(x)^2 + 1/2
#=
for i =1:100
    y3 = sin(x[i])^2 + 1/2 
end
=#
# Out:
# 100-element Vector{Float64}:
#  0.5
#  0.5101683870001501
#  0.5402599636238612
#  0.589050798684915
#  0.6545563958114663
#  0.7341124099544805
#  0.8244830157539749
#  0.9219925200371206
#  1.0226748653009428
#  1.1224349433425393
#  1.2172151578391428
#  1.3031604611869176
#  1.3767751529647223
#  ⋮
#  0.7607181588901828
#  0.6774942297603705
#  0.6073877545568691
#  0.5532502123640236
#  0.5172835691028478
#  0.5009507157644455
#  0.5049159674430634
#  0.5290180432842166
#  0.5722766263492666
#  0.6329322365834776
#  0.7085177951124849
#  0.795958969093304

# %%
?@.
# Out:
#   @. expr
#
#   Convert every function call or operator in expr into a "dot call" (e.g.
#   convert f(x) to f.(x)), and convert every assignment in expr to a "dot
#   assignment" (e.g. convert += to .+=).
#
#   If you want to avoid adding dots for selected function calls in expr, splice
#   those function calls in with $. For example, @. sqrt(abs($sort(x))) is
#   equivalent to sqrt.(abs.(sort(x))) (no dot for sort).
#
#   (@. is equivalent to a call to @__dot__.)
#
#   Examples
#   ≡≡≡≡≡≡≡≡
#
#   julia> x = 1.0:3.0; y = similar(x);
#
#   julia> @. y = x + 3 * sin(x)
#   3-element Vector{Float64}:
#    3.5244129544236893
#    4.727892280477045
#    3.4233600241796016

# %%
plot(x,y3)
plot!(title="Ejemplo con funcion seno")
